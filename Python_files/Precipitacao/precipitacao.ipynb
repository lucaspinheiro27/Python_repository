# %% [markdown]
# ## Carregando bibliotecas

# %%
import numpy as np
import pandas as pd
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn; seaborn.set()

# %% [markdown]
# * Extraindo a precipitação de chuvas em centimetros

# %%
p_chuva = pd.read_csv('precipitation.csv')['precipitation'].values
cent = p_chuva / 254
cent.shape
# Out:
# (5814,)

# %%
plt.hist(cent, 40);
